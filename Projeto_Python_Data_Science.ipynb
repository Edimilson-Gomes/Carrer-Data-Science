# %% [markdown]
# # Python para Data Science
#
# Notebook para o curso de Python para Data Science publicado na plataforma da [Alura](https://www.alura.com.br/)

# %% [markdown]
# # Introdução ao Python
#
# Vamos conhecer o Python, nosso ambiente de estudo e também faremos nosso primeiro código nessa linguagem!

# %% [markdown]
# ## Google Colaboratory
#
# Já aprendemos o que é o [Python](https://www.python.org/) agora vamos aprender a utilzar o [Google Colaboratory](https://colab.research.google.com/) e programar em um notebook.
#
# Vamos testar algumas funções dessa ferramenta.

# %% [markdown]
#  **`>>> Use essa célula para mover <<<`**

# %% [markdown]
# ## Olá mundo!
#
# Vamso conhecer mais como funciona o ambiente interativo de um notebook. Para isso vamos executar nosso primeiro comando em Python: [`print()`](https://docs.python.org/3/library/functions.html#print)

# %%
print('Olá Mundo !')
# Out:
#   File "/tmp/ipython-input-2421257418.py", line 1
#     Print(Olá Mundo !)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('Olá Mundo!')
# Out:
# Olá Mundo!

# %%
print('Hi!')
# Out:
# Hi!

# %%
# Praticando

nome = ('E','d','i')
print('\n'.join(nome))
# Out:
# E
# d
# i

# %% [markdown]
# Vamos ver o que acontece se tentarmos imprimir a tupla `nome` sem o `join()`:

# %% [markdown]
# ### 1. Usando `\n` dentro de uma string
#
# Você pode simplesmente incluir `\n` onde deseja uma quebra de linha dentro de uma string. Quando a string é impressa, `\n` será interpretado como uma nova linha.

# %%
print('Primeira linha\nSegunda linha\nTerceira linha')
# Out:
# Primeira linha
# Segunda linha
# Terceira linha

# %% [markdown]
# ### 2. Usando strings de múltiplas linhas (com aspas triplas)
#
# Para blocos de texto maiores onde você quer manter a formatação visual do código, você pode usar aspas triplas (`'''` ou `"""`). O Python irá automaticamente incluir caracteres de nova linha onde você os digitar no seu código.

# %%
print('''
Esta é a primeira linha.
Esta é a segunda linha.
E esta é a terceira linha.
''')

# %% [markdown]
# Ambas as formas permitem que você controle as quebras de linha diretamente no seu texto, sem a necessidade de um método como `join()`.

# %%
nome = ('E','d','i')
print(nome)
# Out:
# ('E', 'd', 'i')

# %% [markdown]
# Como você pode ver, a tupla é impressa como um todo. O `join('\n', nome)` pega cada elemento da tupla `nome` e os une usando `\n` (nova linha) como separador, criando uma única string onde cada letra está em uma linha diferente. Por exemplo, se `nome` fosse `('E', 'd', 'i')`, `join('\n', nome)` resultaria na string `'E\nd\ni'`.

# %%
#Data do meu Aniversario
dia = 6
mes = 'Novembro'
ano = 1993

print('Meu Aniversário é', dia, 'de', mes, 'de', ano)
# Out:
# Meu Aniversário é 6 de Novembro de 1993

# %% [markdown]
# ---
# # Atenção
# ---
#
# Ao concatenar varias variaveis precisa ter virgula e aspas simples no texto quando fizer o 'PRINT'

# %%
import datetime
AnoAtual = datetime.datetime.now().year
print(AnoAtual)
# Out:
# 2026

# %% [markdown]
# # Manipulando dados
#
# Vamos aprender sobre as variáveis no python, como elas são declaradas e utilizadas além de conhecer outros comandos dentro do Python. :D

# %% [markdown]
# ## Variáveis
#
# Em Data Science nós trabalhamos com vários dados e informações, então é essencial saber trabalhar com variáveis.

# %% [markdown]
# Criamos uma variável no python através da atribuição de um valor a ela.
#
# Para fazer isso, colocamos o nome da variável um sinal de igual (`=`) e o valor que queremos atribuir

# %%
idade = 32

# %%
print(idade)
# Out:
# 32

# %%
idade = 32
print(idade)
# Out:
# 32

# %%
idade
# Out:
# 32

# %%
nome = 'Edi'
nome
# Out:
# 'Edi'

# %% [markdown]
# ---
# #Curiosidade
# No Python nao precisa usar o PRINT para executar uma Variavel
# ---

# %% [markdown]
# Nomes que **não** podemos definir para variáveis:
#
# - **Nomes que começam com números**
#   - Exemplos: `10_notas`, `2_nomes_casa`, etc.
# - **Palavras separada por espaço**
#   - Exemplos: `Nome escola`, `notas estudantes`, etc.
# - **Nomes de funções do Python**
#   - Exemplos: `print`, `type`, etc.

# %% [markdown]
# ```
# # Variáveis
# ```
#
# *   São as definições que adiciono para executar um codigo
# *   Não pode começar com numeros ou são apenas numeros ou palavras
# * nao podem conter espaços
# * e não podem ser funções da IDE como print ou type

# %% [markdown]
# > Letras maiúsculas e minúsculas vão gerar diferentes variáveis. A varíavel `idade` é diferente de `Idade` que por sua vez também é diferente de `IDADE`:
# ``` Python
# idade = 1
# Idade = 2
# IDADE = 3
# _idade = 4
# _idade_ = 5
# print(idade, Idade, IDADE, _idade, _idade_)
# 1 2 3 4 5
# ```

# %% [markdown]
# ## Tipos de variáveis
#
# Cada variável contém uma classe especifica quanto ao tipo de objeto que ela está se referenciando. Essas classes vão ser diferentes a partir do tipo de dado que nós atribuimos a uma variável.
#
# Para saber a classe de cada elemento usamos a função [`type()`](https://docs.python.org/3/library/functions.html#type)

# %% [markdown]
# ---
# #tipos de variaveis
#
# 1. INT = Numero inteiro (1,2.3,10)
# 2. Float = Numero flutuante com pontos, **não podemos usar virgulas** (3.0, 10.4, -0.4)
# 3. Str = São textos ( 'Edi', "Python" )
# 4. Booleana ou Bool = True or False ( traz verdadeiro ou Falso )

# %%
type(5)
# Out:
# int

# %%
type (3.5)
# Out:
# float

# %%
type('Edi')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Em um conjunto de dados escolares podemos ter vários tipos de informações. Digamos que tenhamos acesso à ficha de dados do aluno *Frabicio Daniel* como transformamos ela em variáveis no Python?
#
# #### Ficha:
#
# - Nome: Fabricio Daniel
# - Idade: 15 anos
# - Media do semestre: 8,45
# - Situação de aprovação: Verdadeira (aprovado)

# %%
nome = (str('Fabricio Daniel'))
idade = (int(15))
media = (float(8.45))
aprovado = (bool(True))
print(nome,idade,media,aprovado)
# Out:
# Fabricio Daniel 15 8.45 True

# %% [markdown]
# ## Variáveis numéricas
#
# Entre os tipos de dados numéricos vamos nos focar no tipo `inteiro` e `float`.

# %% [markdown]
# Temos uma tabela de informação de empregos quanto ao cargo, quantidade de pessoas empregadas e o salário correspondente:
#
# |Cargo | Quantidade | Salário|
# |---|---|---|
# |Segurança | 5 | 3000 |
# |Docente | 16| 6000|
# |Diretoria| 1 |12500|
#
# Precisamos trabalhar com esses dados fornecendo:
#
# - A quantidade total de empregados;
# - A diferença entre o salário mais baixo e mais alto; e
# - A média ponderada da faixa salarial da escola.

# %% [markdown]
# ---
# # ATENCAO
# ---
#
# Ao utilizar a função `sum()` em Python para somar múltiplas variáveis, é fundamental agrupá-las em um **iterável**, como uma lista (`[]`) ou uma tupla (`()`).
#
# **Por que isso é necessário?**
#
# A função `sum()` foi projetada para receber um **único argumento** que seja uma coleção de números (um iterável). Ela então percorre cada item dessa coleção e os soma.
#
# *   **Forma Correta:**
#     ```python
#     variavel1 = 5
#     variavel2 = 10
#     variavel3 = 15
#     total = sum([variavel1, variavel2, variavel3]) # Passando uma lista
#     # ou
#     total = sum((variavel1, variavel2, variavel3)) # Passando uma tupla
#     print(total) # Saída: 30
#     ```
#
# Quando você usa os colchetes (`[]`), está criando uma lista *temporária* com os valores das suas variáveis, e é essa lista (o iterável) que a função `sum()` consegue processar corretamente.

# %%
q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500

# %%
q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500

total_empregados = sum((q_seguranca,q_docente,q_diretoria))
print('O total de empregado são:',total_empregados)
# Out:
# O total de empregado são: 22

# %%
#Forma Simples
s_diretoria = 12500
s_docente = 6000
s_seguranca = 3000
diferenca = sum([s_diretoria-s_seguranca])
print('A diferença entre o maior e o menor salario é:',diferenca)

#Forma mais complexa
#cria uma variavel com as variaveis e usa o Max e Min

salarios = (s_diretoria,s_docente,s_seguranca)
maior_salario = max(salarios)
menor_salario = min(salarios)
diferenca = max(salarios) - min(salarios)
print('O maior salario é:',maior_salario)
print('O menor salario é:',menor_salario)
print('A diferença entre o maior e o menor salario é:',diferenca)
# Out:
# A diferença entre o maior e o menor salario é: 9500
# O maior salario é: 12500
# O menor salario é: 3000
# A diferença entre o maior e o menor salario é: 9500

# %%
#Soma de Salarios
salarios = sum([s_diretoria*q_diretoria,s_docente*q_docente,s_seguranca*q_seguranca])
print('A soma dos salarios sao:', salarios)
#Quantidade funcionarios
qtd_funcionarios= sum([q_diretoria,q_docente,q_seguranca])
print('A quantidade de funcionarios é:',qtd_funcionarios)
#Media de Salarios
media_salarios = salarios/qtd_funcionarios
print('A média de salarios é:',media_salarios)
# Out:
# A soma dos salarios sao: 123500
# A quantidade de funcionarios é: 22
# A média de salarios é: 5613.636363636364

# %%
#Exponenciação, elevar potencia
a = 2
b = 3
Potencia = a**b
print(Potencia)
# Out:
# 8

# %%
#Isso é um Módulo (%)
#coloca um limite em uma table ou em uma sequencia de numeros ciclicos, como um contador
#também serve para contar o resto de uma divisao
produtos_por_pagina = 5
total_de_produtos = 30
for i in range(total_de_produtos):
    print(f"Produto {i + 1}", end="\t")
    if (i + 1) % produtos_por_pagina == 0:
        print()  # Inicia uma nova linha (página)
# Out:
# Produto 1	Produto 2	Produto 3	Produto 4	Produto 5
# Produto 6	Produto 7	Produto 8	Produto 9	Produto 10
# Produto 11	Produto 12	Produto 13	Produto 14	Produto 15
# Produto 16	Produto 17	Produto 18	Produto 19	Produto 20
# Produto 21	Produto 22	Produto 23	Produto 24	Produto 25
# Produto 26	Produto 27	Produto 28	Produto 29	Produto 30

# %% [markdown]
# ## Strings

# %% [markdown]
# Strings são caracterizada por ter um conjunto de caracteres formando um texto.
#
# Strigs podem ser criadas ao atribuirmos a uma variável um dado que esteja entre aspas simples (`'`) ou aspas duplas (`"`)

# %%
nome = 'Edimilson Gomes Pinyo'
nomes = "Edimilson Gomes Pinyo"
print(nome)
print(nomes)
print(type(nome),type(nomes))
# Out:
# Edimilson Gomes Pinyo
# Edimilson Gomes Pinyo
# <class 'str'> <class 'str'>

# %% [markdown]
# As variáveis textuais contém vários métodos que nos ajudam a formatar strings. Métódos podem ser executados ao definirmos um objeto seguindo a seguinte estrutura:
#
# ```
# objeto.metodo()
# ```
#
# Existem métodos que não necessitam dos `()`, é preciso verificar a documentação de cada caso.

# %% [markdown]
# ###Lembrete
#
# Métodos são funções atribuidas a um objeto

# %% [markdown]
# ---
# **Situação:**
#
# Recebemos uma variável com o nome de uma professora da escola para inserimos no cadastro. No entanto, precisamos tratar esse texto antes de inserirmos no sistema

# %%
texto = '  Geovana Alessandra dias Sanyos '

# %% [markdown]
# O objetivo final é que o nome esteja da seguinte forma:
#
# ```
# 'GEOVANA ALESSANDRA DIAS SANTOS'
# ```

# %% [markdown]
# ### [`str.upper()` ](https://docs.python.org/3/library/stdtypes.html#str.upper)
# Converte uma string para maiúsculas

# %%
texto  = str.upper(texto)
texto.upper()
texto
# Out:
# '  GEOVANA ALESSANDRA DIAS SANYOS '

# %% [markdown]
# ### [`str.lower()`](https://docs.python.org/3/library/stdtypes.html#str.lower)
# Método converte uma string para minúsculas.

# %%
texto.lower()
# Out:
# '  geovana alessandra dias sanyos '

# %% [markdown]
# ### [`str.strip()`](https://docs.python.org/3/library/stdtypes.html#str.strip)
# Método remove os espaços em branco do início e do fim de uma string.

# %%
texto.strip()
# Out:
# 'GEOVANA ALESSANDRA DIAS SANYOS'

# %% [markdown]
# ### [`str.replace(antigo, novo)`](https://docs.python.org/3/library/stdtypes.html#str.replace)
#
# Método substitui todas as ocorrências do texto "antigo" na string por "novo"

# %%
texto.replace('GEOVANA ALESSANDRA','EDIMILSON GOMES')
# Out:
# '  EDIMILSON GOMES DIAS SANYOS '

# %% [markdown]
# ### Observações
#
# 1. Os métodos retornam uma **tranformação**, não a executam no texto!
#
# 2. Além disso, podemos acumular a execução de métodos.

# %%
texto
# Out:
# '  GEOVANA ALESSANDRA DIAS SANYOS '

# %% [markdown]
# Para que seja executada a transformação nós podemos atribuir às saídas das transformações à variável

# %%
texto.strip().upper().replace('GEOVANA ALESSANDRA','EDIMILSON GOMES').replace('Y','T')
# Out:
# 'EDIMILSON GOMES DIAS SANTOS'

# %% [markdown]
# ## Coletando dados
#
# Em algumas aplicações precisamos coletar valores da pessoa usuária do nosso projeto. Em python conseguimos coletar dados de usuário através do comando [`input()`](https://docs.python.org/3/library/functions.html#input).
#
# Para fazer essa coleta podemos atribuir essa função à uma variável.

# %%
idade = input('Digite sua idade: ')
# Out:
# Digite sua idade: 30

# %%
print(f'Sua idade é: {idade}')
# Out:
# Sua idade é: 30

# %% [markdown]
# O retorno desse comando sempre será uma *string*. Isso quer dizer que mesmo que façamos uma coleta de algo que deva ser numérico, ele será uma string.
#
# Então, será preciso **converter o resultado caso não seja desejável obter uma string**.

# %% [markdown]
# Existem funções para conversão de valores:
#
# - Inteiros: [`int(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#int)
# - Float: [`float(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#float)
# - String: [`str(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#func-str)
# - Booleano: [`bool(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#bool)

# %%
ano_entrada = input('Escreva o ano de ingresso do(a) estudante: ')
# Out:
# Escreva o ano de ingresso do(a) estudante: 90

# %%
type(ano_entrada)
# Out:
# str

# %%
ano_entrada = int(input('Escreva o ano de ingresso do(a) estudante: '))
# Out:
# Escreva o ano de ingresso do(a) estudante: 90

# %%
type(ano_entrada)
# Out:
# int

# %% [markdown]
# Buscaremos apresentar melhor agora o resultado que obtivemos da transformação. Nós conseguimos formatar e apresentar o nosso resultado misturando strings com valores não textuais.
#
# Para fazer isso usamos a estrutura de formatação `f` com strings.

# %%
nota_entrada = float(input('Digite a nota do teste de ingresso: '))
print(f' O Ano de entrada é {ano_entrada} - A nota do teste de ingresso é: {nota_entrada}')
# Out:
# Digite a nota do teste de ingresso: 2
#  O Ano de entrada é 90 - A nota do teste de ingresso é: 2.0

# %% [markdown]
# ### Exercicios

# %% [markdown]
# ###Coleta e amostragem de dados
# 1. Crie um programa que solicite à pessoa usuária digitar seu nome, e imprima “Olá, [nome]!”.
# 2. Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima “Olá, [nome], você tem [idade] anos.”.
# 3. Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima “Olá, [nome], você tem [idade] anos e mede [altura] metros!”.

# %%
#1
nome = str(input('Digite seu nome: '))
print(f'Olá, {nome}!')
# Out:
# Digite seu nome: Edi
# Olá, Edi!

# %%
idade = int(input('Digite sua idade: '))
print(f'Olá, {nome}, você tem {idade} anos.')
# Out:
# Digite sua idade: 32
# Olá, Edi, você tem 32 anos.

# %%
altura = float(input('Digite sua altura: '))
print(f'Olá, {nome}, você tem {idade} anos e mede {altura} metros!')
# Out:
# Digite sua altura: 1.70
# Olá, Edi, você tem 32 anos e mede 1.7 metros!

# %% [markdown]
# ###Calculadora com operadores
# 1. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.
# 2. Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.
# 3. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.
# 4. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.
# 5. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
# 6. Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.
# 7. Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
# 8. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
# 9. Crie um código que solicita 3 notas de um estudante e imprima a média das notas.
# 10. Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.

# %%
#1 input 2 numero e soma
a = int(input('Digite um numero: '))
b = int(input('Digite outro numero: '))
print(f'A soma dos numeros é: {a+b}')
# Out:
# Digite um numero: 1
# Digite outro numero: 2
# A soma dos numeros é: 3

# %%
#2 input 3 numeros e soma

c = int(input('Digite um numero: '))
d = int(input('Digite outro numero: '))
e = int(input('Digite outro numero: '))
print(f'A soma dos numeros é: {c+d+e}')
# Out:
# Digite um numero: 1
# Digite outro numero: 1
# Digite outro numero: 1
# A soma dos numeros é: 3

# %%
#3 input 2 numeros e subtraia
f = int(input('Digite um numero: '))
g = int(input('Digite outro numero: '))
print(f'A subtração dos numeros é: {f-g}')
# Out:
# Digite um numero: 1
# Digite outro numero: 1
# A subtração dos numeros é: 0

# %%
#4 input 2 numeros e multiplica
h = int(input('Digite um numero: '))
i = int(input('Digite outro numero: '))
print(f'A multiplicação dos numeros é: {h*i}')
# Out:
# Digite um numero: 2
# Digite outro numero: 2
# A multiplicação dos numeros é: 4

# %%
#5 input 2 numeros e divida
j = int(input('Digite um numero: '))
k = int(input('Digite outro numero: '))
print(f'A divisão dos numeros é: {j/k}')
# Out:
# Digite um numero: 1
# Digite outro numero: 1
# A divisão dos numeros é: 1.0

# %%
#6 input 2 numeros e eleva ele ao outro numero
l = int(input('Digite um numero: '))
m = int(input('Digite numero da elevação: '))
print(f'O numero {l} elevado a {m} é: {l**m}')
# Out:
# Digite um numero: 2
# Digite numero da elevação: 2
# O numero 2 elevado a 2 é: 4

# %%
#7 input 2 numero e divida inteiro
n = int(input('Digite um numero: '))
o = int(input('Digite outro numero: '))
print(f'A divisão inteira dos numeros é: {n//o}')
# Out:
# Digite um numero: 10
# Digite outro numero: 2
# A divisão inteira dos numeros é: 5

# %%
#8 usar o modulo para descobrir o resto da divisao
p = int(input('Digite um numero: '))
q = int(input('Digite outro numero: '))
print(f'O resto da divisão dos numeros é: {p%q}')
# Out:
# Digite um numero: 5
# Digite outro numero: 3
# O resto da divisão dos numeros é: 2

# %%
#9 input 3 notas e consiga a media
nota_1 = float(input('Digite a 1° nota: '))
nota_2 = float(input('Digite a 2° nota: '))
nota_3 = float(input('Digite a 3° nota: '))
print(f'Média: {(nota_1+nota_2+nota_3)/3}')
# Out:
# Digite a 1° nota: 10
# Digite a 2° nota: 5
# Digite a 3° nota: 8
# Média: 7.666666666666667

# %%
#10 input 3 notas e consiga a media ponderada
a,b,c,d = 5,12,20,15
peso1,peso2,peso3,peso4 = 1,2,3,4
#1º soma os produtos a * peso + b * peso
soma_numeros = sum([a*peso1,b*peso2,c*peso3,d*peso4])
print(f'A soma dos produtos é: {soma_numeros}')
#2º soma os pesos
soma_pesos = sum([peso1,peso2,peso3,peso4])
print(f'A soma dos pesos é: {soma_pesos}')
#3º divida a soma dos produtos pela soma dos pesos
media_ponderada = soma_numeros/soma_pesos
print(f'A média ponderada é: {media_ponderada}')
# Out:
# A soma dos produtos é: 149
# A soma dos pesos é: 10
# A média ponderada é: 14.9

# %% [markdown]
# # Estruturas condicionais

# %% [markdown]
# ## `IF` e `ELSE`
#
# O `if` e `else` são duas estruturas condicionais. O `if` executará o bloco de comando caso a condição colocada for **verdadeira**. O `else` é um caso em que a condicional de `if` seja **falsa**.

# %% [markdown]
# O `if` é uma palavra-chave em Python que significa "se". Ele é usado para formar uma estrutura condicional, que permite que você verifique se uma determinada condição é verdadeira ou falsa e, em seguida, execute um bloco de código específico dependendo do resultado da verificação. A sintaxe para usar o `if` é:
#
#
#
# ```
# if condição:
#     # faça algo
# ```

# %% [markdown]
# Já o `else` em Python é usada em conjunto com a palavra-chave `if` para formar uma estrutura condicional. A sintaxe para usar o `else` é:
#
# ```
# if condição:
#   # código caso seja verdade
# else:
#   # código caso seja falso
# ```
#
# O `else` é executado quando a condição verificada pelo `if` é avaliada como `False`.

# %% [markdown]
# ---
# **Situação:**
#
# Receberemos a média de estudantes e precisamos de um algoritmo que execute a análise e decida se esse estudante está **Aprovado** ou Reprovado, mostrando uma mensagem do resultado. Para ser aprovado, a média precisa ser igual ou superior à 6.0.

# %%
media = float(input('Digite a média: '))

# %% [markdown]
# Agora a nossa instituição de ensino lançou uma nota oficial que pessoas que tenham média entre 4.0 e 6.0 podem fazer os cursos de **Recuperação** nas férias para poder recuperar a nota.
#
# Então podemos agora fazer um conjunto de `if`s para que possamos estruturar essa nova condição.

# %%
media = float(input('Digite a média: '))

# %% [markdown]
# Notemos que em casos com 3 situações como esse precisamos definir bem nossas condições. Pois foi feita uma construção com `else` no final, ele irá considerar apenas a alguma condicional para ser o caso **falso** podendo resultar em duas (ou mais) execuções.
#
# Por exemplo:

# %%
media = float(input('Digite a média: '))

# %% [markdown]
# ## `ELIF`
#
# O `elif` é uma palavra-chave em Python que significa "senão, se" e pode ser considerado uma união do `else` com um `if`. Ela é usada em conjunto com a palavra-chave `if` para formar uma estrutura condicional encadeada.

# %% [markdown]
# A sintaxe para usar o `elif` é:
#
# ```
# if condição1:
#     # faça algo
# elif condição2:
#     # faça outra coisa
# elif condição3:
#     # faça mais alguma coisa
# else:
#     # faça algo diferente
# ```
#
# O `elif` permite que você verifique várias condições de forma encadeada, economizando espaço em seu código. Se a primeira condição for avaliada como `False`, o interpretador Python avaliará a próxima condição no `elif`. Isso continuará até que uma condição seja avaliada como `True` ou até que o `else` seja atingido. Se nenhuma das condições forem avaliadas como `True`, a execução do código do `else` será iniciada.

# %% [markdown]
# Vamos usar o mesmo caso anterior:

# %%
media = float(input('Digite a média: '))

# %% [markdown]
# ## Operadores
#
# Durante a construção de comandos por vezes precisamos de uma elaboração maior de da expressão condicional, necessitando que alguns operadores lógicos estejam integrados.

# %% [markdown]
# ### `AND`, `OR`, `NOT`
#
# Os operadores lógicos `and`, `or` e `not` são usados para combinar expressões lógicas em Python. Eles são usados frequentemente em conjunto com o `if` para criar estruturas condicionais mais complexas.

# %% [markdown]
# - `AND` é usado para verificar se duas condições são verdadeiras. A expressão lógica¹ `x and y` é avaliada como `True` apenas se **ambas as condições `x` e `y` forem verdadeiras**, e como `False` caso contrário.
#
# - `OR` é usado para verificar se pelo menos uma das condições é verdadeira. A expressão lógica `x or y` é avaliada como `True` **se pelo menos uma das condições `x` ou `y` for verdadeira**, e como `False` se ambas forem falsas.
#
# - `NOT` é usado para **negar uma condição**. A expressão lógica not x é avaliada como True se a condição x for falsa, e como False se a condição x for verdadeira.
#
# ¹ Uma expressão lógica é uma declaração que pode ser avaliada como verdadeira ou falsa. Ela é composta por operandos lógicos² e operadores lógicos³, que são usados ​​para combinar várias expressões lógicas em uma única expressão.
#
# ² Os operandos lógicos são os elementos que são comparados ou avaliados em uma expressão lógica. Eles são geralmente valores verdadeiros ou falsos, mas também podem ser expressões lógicas mais complexas. Em Python, os operandos lógicos são os valores `True` e `False`.
#
# ³ Os operadores lógicos são os símbolos ou palavras-chave que são usados ​​para combinar várias expressões lógicas em uma única expressão. Em Python, os operadores lógicos são `and`, `or` e `not`, bem como as palavras-chave `if`, `elif` e `else`.

# %%
if :
  print('expressão verdadeira')
else:
  print('expressão falsa')

# %%
if :
  print('expressão verdadeira')
else:
  print('expressão falsa')

# %%
if :
  print('expressão verdadeira')
else:
  print('expressão falsa')

# %% [markdown]
# ### `IN`
#
# É usado para verificar se um elemento está presente em uma lista, tupla ou outra variável de conjunto. A expressão `x in y` é avaliada como `True` se o elemento `x` estiver presente na variável de conjunto `y`, e como `False` caso contrário.

# %% [markdown]
# Podemos verificar isso com variáveis de texto.
#
# ---
#
# **Situação:**
#
# Na escola foi passada uma lista com nomes de estudantes que foram aprovados por média no semestre, mas é preciso verificar se alguns nomes estão nessa lista para verificar se os dados estão corretos.
#
# A lista distribuida pode ser observada abaixo:
#
# ```
# lista = 'José da Silva, Maria Oliveira, Pedro Martins, Ana Souza, Carlos Rodrigues, Juliana Santos, Bruno Gomes, Beatriz Costa, Felipe Almeida, Mariana Fernandes, João Pinto, Luísa Nascimento, Gabriel Souza, Manuela Santos, Thiago Oliveira, Sofia Ferreira, Rafael Albuquerque, Isabella Gomes, Bruno Costa, Maria Martins, Rafaela Souza, Matheus Fernandes, Luísa Almeida, Beatriz Pinto, Mariana Rodrigues, Gabriel Nascimento, João Ferreira, Maria Albuquerque, Felipe Oliveira
# '
# ```
#
# Os nomes que precisam ser verificados são os seguintes:
#
# ```
# nome_1 = 'Mariana Rodrigues'
# nome_2 = 'Marcelo Nogueira'
# ```

# %%
lista = 'José da Silva, Maria Oliveira, Pedro Martins, Ana Souza, Carlos Rodrigues, Juliana Santos, Bruno Gomes, Beatriz Costa, Felipe Almeida, Mariana Fernandes, João Pinto, Luísa Nascimento, Gabriel Souza, Manuela Santos, Thiago Oliveira, Sofia Ferreira, Rafael Albuquerque, Isabella Gomes, Bruno Costa, Maria Martins, Rafaela Souza, Matheus Fernandes, Luísa Almeida, Beatriz Pinto, Mariana Rodrigues, Gabriel Nascimento, João Ferreira, Maria Albuquerque, Felipe Oliveira'
lista
# Out:
# 'José da Silva, Maria Oliveira, Pedro Martins, Ana Souza, Carlos Rodrigues, Juliana Santos, Bruno Gomes, Beatriz Costa, Felipe Almeida, Mariana Fernandes, João Pinto, Luísa Nascimento, Gabriel Souza, Manuela Santos, Thiago Oliveira, Sofia Ferreira, Rafael Albuquerque, Isabella Gomes, Bruno Costa, Maria Martins, Rafaela Souza, Matheus Fernandes, Luísa Almeida, Beatriz Pinto, Mariana Rodrigues, Gabriel Nascimento, João Ferreira, Maria Albuquerque, Felipe Oliveira'

# %%
nome_1 = 'Mariana Rodrigues'
nome_2 = 'Marcelo Nogueira'

# %% [markdown]
# # Estruturas de repetição

# %% [markdown]
# Quando temos que executar um mesmo bloco de comandos por várias vezes não é muito interessante fazer isso à mão.
#
# Imaginemos a situação de termos que coletar e imprimir a média de duas notas de **3 estudantes**:

# %%
nota_1 = float(input('Digite a 1° nota: '))
nota_2 = float(input('Digite a 2° nota: '))

print(f'Média: {(nota_1+nota_2)/2}')

# %% [markdown]
# Agora imaginemos uma situação em que não são apenas 3 estudantes, mas sim 100 estudantes. Não seria interessante repetir o mesmo código por 100 vezes, mas sim **executar o mesmo código 100 vezes**.
#
# Essa repetição conseguimos construir com laços de repetição!

# %% [markdown]
# ## `WHILE`

# %% [markdown]
# O laço `while` é uma estrutura de controle de repetição em Python que permite executar um bloco de código repetidamente enquanto uma determinada condição é verdadeira. Sua estrutura é:
#
#
#
# ```
# while condição:
#     # bloco de código
# ```
#
# Vamos construir um exemplo com um contador de 1 até 10.

# %% [markdown]
# Agora vamos coletar as notas e médias de cada aluno dentro do while. Faremos um exemplo com 3 médias.

# %% [markdown]
# ## `FOR`

# %% [markdown]
# O laço `for` é um tipo de estrutura de controle de fluxo em Python que permite iterar sobre um conjunto de elementos. A sua estrutura é:
#
#
#
# ```
# for elemento in conjunto:
#     # código a ser executado para cada elemento
# ```
#
# O laço for itera sobre cada elemento do conjunto especificado e executa o bloco de código dentro do laço para cada elemento. Quando o laço chega ao final do conjunto, ele é interrompido e o programa continua a execução após o laço.

# %% [markdown]
# O conjunto pode ser gerado com a função [`range()`](https://docs.python.org/3/library/functions.html#func-range). Que é uma função capaz de gerar uma sequência de números inteiros. A estrutura dessa função é:
#
# ```
# range(inicio, fim, passo)
# ```
#
# Segundo a documentação, o `range()` gera uma sequência de números inteiros a partir do valor do parâmetro `inicio` até o valor do parâmetro `fim`, de acordo com o valor do parâmetro `passo`. Se `inicio` não for especificado, o valor padrão é 0. Se `passo` não for especificado, o valor padrão é 1.

# %% [markdown]
# Vamos fazer o mesmo contador `while` agora com `for`.

# %% [markdown]
# # Estruturas de dados

# %% [markdown]
# Um conjunto de elementos é uma coleção de itens, que são armazenados juntos de maneira organizada. Alguns exemplos de conjuntos de elementos em Python são listas, strings e dicionários.

# %% [markdown]
# ## Listas

# %% [markdown]
# As listas podem armazenar uma coleção de itens em ordem. Eles são delimitados por colchetes `[]` e os itens são separados por vírgulas.
#
# Elas também podem armazenar qualquer tipo de item, incluindo números, strings, objetos e outras listas. Elas também podem armazenar itens de tipos de dados diferentes juntos em uma única lista.

# %% [markdown]
# As listas são organizadas em Python porque **cada elemento da lista tem um índice que indica sua posição na lista**. Os índices começam em 0 e vão até o tamanho da lista menos 1.

# %% [markdown]
# Temos então 5 elementos com índices variando de 0 a 4, ordenadamente:
#
# ```
# #             [0]           [1]   [2]   [3]    [4]
# lista = ['Fabricio Daniel', 9.5 , 9.0 , 8.0 , True]
# ```
#
# Em Python temos também os índices **negativos** que se iniciam no último elemento com o valor de `-1` e depois avancam no universo dos negativos até chegar no 1° elemeno:
#
# ```
# #             [-5]         [-4]  [-3]  [-2]   [-1]
# lista = ['Fabricio Daniel', 9.5 , 9.0 , 8.0 , True]
# ```
#
# Conseguimos selecionar separadamente cada elemento através de seus respectivos índices. Colocando o nome da lista e em seguida o índice a ser selecionado.

# %% [markdown]
# Uma forma mais dinâmica de trabalhar item por item de uma lista é utilizando um laço for para leitura elemento a elemento.

# %% [markdown]
# A nota `8.0` de Fabricio Daniel precisa ser ajustada pois ganhou 2 pontos em sua ultima nota por fazer um trabalho de turma. Então é necessária fazer uma troca no valor do índice `3` de `8.0` para `10.0`.

# %% [markdown]
# conseguimos calcular a média do aluno a partir dos dados que temos

# %%
media = (lista[1] + lista[2] + lista[3])/3
media

# %% [markdown]
# ## Manipulação de listas
#
# As listas são muito úteis em Python porque permitem armazenar e acessar uma coleção de itens de maneira organizada e rápida. Elas também oferecem muitos métodos úteis para manipular os itens armazenados, como adicionar, remover, classificar e pesquisar elementos.

# %% [markdown]
# #### Quantidade de elementos
#
# Usamos a função [`len()`](https://docs.python.org/3/library/functions.html#len) para descobrimos a quantidade de elementos de um conjunto.

# %% [markdown]
# #### Partição
#
# A partição de listas por indexação em Python é uma técnica muito útil para selecionar um subconjunto de elementos de uma lista. Ela é feita usando a sintaxe `lista[inicio:fim]`, onde `inicio` é o índice do primeiro elemento a ser incluído na partição e `fim` é o índice do primeiro elemento a ser excluído da partição.

# %%
lista[1:3]

# %%
lista[3:]

# %% [markdown]
# #### [`append()`](https://docs.python.org/3/tutorial/datastructures.html#:~:text=of%20list%20objects%3A-,list.append(x),-Add%20an%20item)
#
# Adiciona um elemento ao final da lista.

# %% [markdown]
# #### [`extend()`](https://docs.python.org/3/tutorial/datastructures.html#:~:text=list.extend(iterable))
#
# Adiciona vários elementos ao final da lista.
#
# Adicionaremos as notas `[10.0,8.0,9.0]` na lista do Fabricio Daniel

# %% [markdown]
# *Isso não é possivel ser feito com o* `append`.

# %% [markdown]
# #### [`remove()`](https://docs.python.org/3/tutorial/datastructures.html#:~:text=append(x).-,list.remove(x),-Remove%20the%20first)
#
# Remove um elemento específico da lista.

# %% [markdown]
# ## Dicionário

# %% [markdown]
# Os dicionários são um tipo de estrutura de dados que armazenam pares de *chave-valor*. Eles são delimitados por chaves `{}` e os pares *chave-valor* são separados por vírgulas.
#
# ```
# dicionário = {chave: valor}
# ```
#
# A **chave** é um elemento único que identifica um valor no dicionário, enquanto o **valor** é o item que é armazenado para a chave. As chaves e os valores podem ser de **qualquer tipo de dado**.
#
# Os dicionários são úteis para armazenar e acessar dados de maneira organizada e rápida. Eles são um tipo de conjunto de elementos em Python, pois armazenam uma coleção de itens.

# %% [markdown]
# ---
# **Situação:**
#
# Vamos criar um conjunto de dados com informações de matricula de um estudante. Os dados são os seguintes:
#
# - matricula: 2000168933
# - dia de cadastro: 25
# - mês de cadastro: 10
# - turma: 2E

# %% [markdown]
# É possível substituir os valores dentro de uma chave. Por exemplo, recebemos a informação que a turma do estudante que cadastramos foi trocada para `'2G'` e agora precisamos trocar o valor da chave `'turma'`.

# %% [markdown]
# Podemos também adicionar outros dados ao dicionário. Vamos adicionar a informação de modalidade de ensino, nosso estudante atuará inicialmente em modalidade EAD.
#
# Então iremos definir uma chave chamada `'modalidade'` e o valor `'EAD'`.

# %% [markdown]
# ## Aprofundando em dicionários

# %% [markdown]
# #### [`pop()`](https://python-reference.readthedocs.io/en/latest/docs/dict/pop.html)
# Remove um item de um dicionário e o retorna.

# %%
cadastro

# %% [markdown]
# #### [`items()`](https://python-reference.readthedocs.io/en/latest/docs/dict/items.html)
# Retorna uma lista de pares chave-valor do dicionário.

# %% [markdown]
# #### [`keys()`](https://python-reference.readthedocs.io/en/latest/docs/dict/keys.html)
# Retorna uma lista das chaves do dicionário.

# %% [markdown]
# #### [`values()`](https://python-reference.readthedocs.io/en/latest/docs/dict/values.html)
# Retorna uma lista dos valores do dicionário.

# %% [markdown]
# ### Leitura de valores com `for`

# %% [markdown]
# # Task
# Refactor the code in cell `_vYH7ZX9511r` to define lists for numbers and weights, calculate the sum of products and the sum of weights, and then calculate and print the weighted average in a generic way.

# %% [markdown]
# ## Calcular e Imprimir Média Ponderada
#
# ### Subtask:
# Refatorar o código na célula `_vYH7ZX9511r` para definir listas de números e pesos, calcular a soma dos produtos e a soma dos pesos, e então calcular e imprimir a média ponderada de forma genérica.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The task involved refactoring existing code to implement a generic weighted average calculation.
# *   The process required defining separate lists for numbers and their corresponding weights.
# *   The weighted average was calculated by summing the products of each number and its weight, and then dividing this sum by the total sum of the weights.
#
# ### Insights or Next Steps
# *   This generic approach allows for easy recalculation of the weighted average with different sets of numbers and weights by simply updating the input lists.
